# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")

income_stmt = ticker.financials
balance_sheet = ticker.balance_sheet
cash_flow = ticker.cashflow
info = ticker.info

# %%
import requests
symbol = "AAPL"  # Apple
api_key="d1l719pr01qt4thec1pgd1l719pr01qt4thec1q0"
url = f"https://finnhub.io/api/v1/company-news?symbol={symbol}&from=2025-01-01&to=2025-01-31&token={api_key}"

response = requests.get(url)
news = response.json()

for item in news[:5]:
    print(item['datetime'], item['headline'])
    print(item['summary'])
    print(item['url'])
    print('-' * 80)
# Out:
# 1738349280 The Stock Market Weathered Nvidia’s Plunge. It Couldn’t Withstand Renewed Tariff Threats.
# The Stock Market Weathered Nvidia’s Plunge. It Couldn’t Withstand Renewed Tariff Threats.
# https://finnhub.io/api/news?id=411087521c8479c2a2fedcfd419a66789e95fe3909c2011c0de4915cd546fef7
# --------------------------------------------------------------------------------
# 1738346760 Apple Q1 Earnings: Services Growth And Margin Expansion Make It A Buy
# Apple is set to continue pumping out innovations that will generate continued margin expansion, sales growth, and product superiority. Learn more on AAPL stock here.
# https://finnhub.io/api/news?id=7ddaafbc9ef6ff9e8886996ed7251398e20a8a8f2a4b67933470cf8036f71c46
# --------------------------------------------------------------------------------
# 1738343611 White House Faces Delicate Balancing Act On AI Chips
# White House Faces Delicate Balancing Act On AI Chips
# ...

# %%
news
# Out:
# [{'category': 'company',
#   'datetime': 1738349280,
#   'headline': 'The Stock Market Weathered Nvidia’s Plunge. It Couldn’t Withstand Renewed Tariff Threats.',
#   'id': 132520621,
#   'image': '',
#   'related': 'AAPL',
#   'source': 'MarketWatch',
#   'summary': 'The Stock Market Weathered Nvidia’s Plunge. It Couldn’t Withstand Renewed Tariff Threats.',
#   'url': 'https://finnhub.io/api/news?id=411087521c8479c2a2fedcfd419a66789e95fe3909c2011c0de4915cd546fef7'},
#  {'category': 'company',
#   'datetime': 1738346760,
#   'headline': 'Apple Q1 Earnings: Services Growth And Margin Expansion Make It A Buy',
#   'id': 132506889,
#   'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1486989073/image_1486989073.jpg?io=getty-c-w1536',
#   'related': 'AAPL',
#   'source': 'SeekingAlpha',
#   'summary': 'Apple is set to continue pumping out innovations that will generate continued margin expansion, sales growth, and product superiority. Learn more on AAPL stock here.',
# ...
